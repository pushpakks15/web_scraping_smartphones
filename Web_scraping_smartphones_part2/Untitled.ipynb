# %%
#Importing the html file
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\pushpak\appdata\local\programs\python\python311\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\pushpak\appdata\local\programs\python\python311\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pushpak\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->bs4) (2.4.1)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\pushpak\appdata\local\programs\python\python311\lib\site-packages (4.9.3)

# %%
#importing libraries
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
#creating soup object
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
data = {
    'model': names,
    'price': prices,
    'rating': ratings,
    'sim': sim,
    'processor': processor,
    'ram': ram,
    'battery': battery,
    'display': display,
    'camera': camera,
    'card': card,
    'os': os
}

df = pd.DataFrame(data)

# %%
df
# Out:
#                               model    price rating  \
# 0         OnePlus Nord CE 3 Lite 5G  ₹19,999     85
# 1                        Realme C53   ₹9,999     75
# 2       Realme C53 (6GB RAM + 64GB)  ₹10,999     76
# 3     Vivo T2x 5G (6GB RAM + 128GB)  ₹13,999     78
# 4                      OPPO Reno 10  ₹32,999     88
# ...                             ...      ...    ...
# 1015               Snexian Bold 12K   ₹1,199    NaN
# 1016                    Kechaoda K7   ₹1,349    NaN
# 1017                   Lvix L1 L300     ₹699    NaN
# 1018                  iKall K15 New     ₹841    NaN
# 1019                  iKall K52 New     ₹839    NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 2                        Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...                                                 ...
# 1015                                           Dual Sim
# 1016                                           Dual Sim
# 1017                                           Dual Sim
# 1018                                           Dual Sim
# 1019                                           Dual Sim
#
#                                             processor  \
# 0     Snapdragon 695 5G, Octa Core, 2.2 GHz Processor
# 1           Tiger T612, Octa Core, 1.82 GHz Processor
# 2           Tiger T612, Octa Core, 1.82 GHz Processor
# 3        Dimensity 6020, Octa Core, 2.2 GHz Processor
# 4        Dimensity 7050, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015                                          No Wifi
# 1016                                100 kHz Processor
# 1017                                1.3 MHz Processor
# 1018                         32 MB RAM, 64 MB inbuilt
# 1019                         32 MB RAM, 64 MB inbuilt
#
#                            ram                                  battery  \
# 0     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 1     4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 2      6 GB RAM, 64 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 3     6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 4     8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# ...                        ...                                      ...
# 1015           1 MHz Processor                 32 MB RAM, 32 MB inbuilt
# 1016  32 MB RAM, 32 MB inbuilt                         1800 mAh Battery
# 1017  32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 1018          1000 mAh Battery         1.8 inches, 180 x 220 px Display
# 1019          1000 mAh Battery         1.8 inches, 180 x 220 px Display
#
#                                                 display  \
# 0     6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1     6.74 inches, 1080 x 2400 px, 90 Hz Display wit...
# 2     6.74 inches, 1080 x 2400 px, 90 Hz Display wit...
# 3     6.58 inches, 1080 x 2408 px Display with Water...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015                                   2500 mAh Battery
# 1016                   2.4 inches, 320 x 240 px Display
# 1017                  1.77 inches, 240 x 320 px Display
# 1018                                     No Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                                  camera  \
# 0     108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 1           108 MP + 2 MP Dual Rear & 8 MP Front Camera
# 2           108 MP + 2 MP Dual Rear & 8 MP Front Camera
# 3            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 4     64 MP + 32 MP + 8 MP Triple Rear & 32 MP Front...
# ...                                                 ...
# 1015                   2.8 inches, 240 x 320 px Display
# 1016                                     No Rear Camera
# 1017                                 0.3 MP Rear Camera
# 1018                  Memory Card Supported, upto 32 GB
# 1019                  Memory Card Supported, upto 32 GB
#
#                                   card                                 os
# 0      Memory Card (Hybrid), upto 1 TB                        Android v13
# 1     Memory Card Supported, upto 2 TB                        Android v13
# 2     Memory Card Supported, upto 2 TB                        Android v13
# 3      Memory Card (Hybrid), upto 1 TB                        Android v13
# 4                 Memory Card (Hybrid)                        Android v13
# ...                                ...                                ...
# 1015     1.3 MP Rear & No Front Camera  Memory Card Supported, upto 32 GB
# 1016             Memory Card Supported                                NaN
# 1017             Memory Card Supported                                NaN
# 1018                         Bluetooth                                NaN
# 1019                         Bluetooth                                NaN
#
# [1020 rows x 11 columns]

# %%
df.to_csv()
# Out:
# ',model,price,rating,sim,processor,ram,battery,display,camera,card,os\r\n0,OnePlus Nord CE 3 Lite 5G,"₹19,999",85,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi","Snapdragon 695 5G, Octa Core, 2.2\u2009GHz Processor","8\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 67W Fast Charging,"6.72 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole",108\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera,"Memory Card (Hybrid), upto 1\u2009TB",Android v13\r\n1,Realme C53,"₹9,999",75,"Dual Sim, 3G, 4G, VoLTE, Wi-Fi","Tiger T612, Octa Core, 1.82\u2009GHz Processor","4\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 18W Fast Charging,"6.74 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Water Drop Notch",108\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera,"Memory Card Supported, upto 2\u2009TB",Android v13\r\n2,Realme C53 (6GB RAM + 64GB),"₹10,999",76,"Dual Sim, 3G, 4G, VoLTE, Wi-Fi","Tiger T612, Octa Core, 1.82\u2009GHz Processor","6\u2009GB RAM, 64\u2009GB inbuilt",5000\u2009mAh Battery with 18W Fast Charging,"6.74 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Water Drop Notch",108\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera,"Memory Card Supported, upto 2\u2009TB",Android v13\r\n3,Vivo T2x 5G (6GB RAM + 128GB),"₹13,999",78,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi","Dimensity 6020, Octa Core, 2.2\u2009GHz Processor","6\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 18W Fast Charging,"6.58 inches, 1080\u2009x\u20092408\u2009px Display with Water Drop Notch",50\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera,"Memory Card (Hybrid), upto 1\u2009TB",Android v13\r\n4,OPPO Reno 10,"₹32,999",88,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster","Dimensity 7050, Octa Core, 2.6\u2009GHz Processor","8\u2009GB RAM, 256\u2009GB inbuilt",5000\u2009mAh Battery with 67W Fast Charging,"6.7 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole",64\u2009MP + 32\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera,Memory Card (Hybrid),Android v13\r\n5,Motorola Moto G14,"₹9,999",69,"Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC","Tiger  T616, Octa Core, 2\u2009GHz Processor","4\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 20W Fast Charging,"6.5 inches, Full HD+ Display with Punch Hole",50\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera,"Memory Card Supported, upto 1\u2009TB",Android v13\r\n6,Realme 11 Pro,"₹23,599",85,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC","Dimensity 7050, Octa Core, 2.6\u2009GHz Processor","8\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 67W Fast Charging,"6.7 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole",100\u2009MP + 2\u2009MP Dual Rear & 16\u2009MP Front Camera,Android v13,No FM Radio\r\n7,Motorola Edge 40 5G,"₹29,999",87,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC","Dimensity 8020, Octa Core, 2.6\u2009GHz Processor","8\u2009GB RAM, 256\u2009GB inbuilt",4400\u2009mAh Battery with 68W Fast Charging,"6.55 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display",50\u2009MP + 13\u2009MP Dual Rear & 32\u2009MP Front Camera,Android v13,Bluetooth\r\n8,OnePlus Nord 3 5G,"₹33,298",85,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster","Dimensity 9000, Octa Core, 3.05\u2009GHz Processor","8\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 80W Fast Charging,"6.74 inches, 1240\u2009x\u20092772\u2009px, 120 Hz Display with Punch Hole",50\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera,Android v13,No FM Radio\r\n9,Realme Narzo 60 5G,"₹17,999",82,"Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi","Dimensity 6020, Octa Core, 2.2\u2009GHz Processor","8\u2009GB RAM, 128\u2009GB inbuilt",5000\u2009mAh Battery with 33W Fast Charging,"6.43 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole",64\u2009MP + 2\u2009MP Dual Rear & 16\u2009MP Front Camera,"Memory Card Supported, upto 1\u2009TB",Android v13\r\n10,Samsung Galaxy M34 5G,"₹18,999",82 ...
